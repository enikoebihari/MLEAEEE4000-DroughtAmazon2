# %% [markdown]
# # Setup

# %%
# do this before anything else because you don't want to have to rerun this 
# every time you need to install something new - pain in the ass

# Install Earth Engine API
# !pip install -q earthengine-api 

# import ee
import ee
# from ee.oauth import get_credentials_path
# print(get_credentials_path())

# Authenticate Earth Engine
ee.Authenticate(force=True)
print('GEE authenticated')
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/drive%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=F9im9hotiM4lAFEmInGFl2RYuXkeH8Keg7oI9tsvSRc&tc=cweBO2WbnZJkh2y7svpUg-Oz-VoJb1VjYJ0Mu5pxLVc&cc=xYxX_Lptr4KFlJVZWKXFQIqUAGtSw86wfg7dqT_nasE>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/drive%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=F9im9hotiM4lAFEmInGFl2RYuXkeH8Keg7oI9tsvSRc&tc=cweBO2WbnZJkh2y7svpUg-Oz-VoJb1VjYJ0Mu5pxLVc&cc=xYxX_Lptr4KFlJVZWKXFQIqUAGtSw86wfg7dqT_nasE</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code:  4/1Ab32j90UXkIhExu8ssCu-KVUonevuo9GGDuUYAaXudI5MHtGh5LADmH8BpI
# Successfully saved authorization token.
# GEE authenticated

# %%
# Initialize Earth Engine
ee.Initialize(project='columbia-phd')
print('GEE initialized')

# import whatever else you need
from datetime import datetime
import os
import rasterio
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import ListedColormap
# GEEmap for visualization
# !pip install -q geemap
# !pip install -q ipywidgets geemap
# !pip install -q ipywidgets geemap jupyterlab_widgets
import geemap
print('GEE imported')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# GEE initialized
# GEE imported

# %%
# import data

# AOI 
# -----------------------------------------------------------------------------------------------------

faoFC = ee.FeatureCollection("FAO/GAUL/2015/level2")
aoiFC = faoFC.filter(ee.Filter.eq('ADM1_NAME', 'Madre de Dios'))
# print(aoiFC)

# TerraClim
# -----------------------------------------------------------------------------------------------------

# https://developers.google.com/earth-engine/datasets/catalog/IDAHO_EPSCOR_TERRACLIMATE
terraClimIC = (
    ee.ImageCollection('IDAHO_EPSCOR/TERRACLIMATE')
    .filter(ee.Filter.date('2000-01-01', '2024-12-31'))
    .select(['tmmx', 'tmmn', 'pr','pdsi','def','vpd','soil'])
    .map(lambda img: img.clip(aoiFC))
)
# print(terraClimIC)

res = terraClimIC.first().projection().nominalScale().getInfo()

# print pixel size
print('pixel size:', res) 
print('band names:', terraClimIC.first().bandNames().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# pixel size: 4638.312116386398
# band names: ['tmmx', 'tmmn', 'pr', 'pdsi', 'def', 'vpd', 'soil']

# %%
# scale values according to Terraclim metadata

# define scaling factors for each band
scales = {
    'tmmx': 0.1,
    'tmmn': 0.1,
    'pr': 1,
    'pdsi': 0.01,
    'def': 0.1,
    'vpd': 0.01,
    'soil': 0.1
}

# define a function that scales each band in an image
def scale_bands(img):
    
    # Multiply each band by its scale
    scaled = img.select(list(scales.keys())) \
                .multiply(ee.Image.constant(list(scales.values())))
    
    # Preserve band names
    scaled = scaled.rename(list(scales.keys()))
    
    return scaled.copyProperties(img, img.propertyNames())

# Apply to the collection
terraClimIC_scaled = terraClimIC.map(scale_bands)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Create map
m = geemap.Map()
m.centerObject(aoiFC, zoom=7)

# get min and max values for visualization
terraClim_mean = terraClimIC_scaled.median()
minMaxStats = terraClim_mean.reduceRegion(
    reducer=ee.Reducer.minMax(),
    geometry=aoiFC,          
    scale=res,              
    maxPixels=1e13
)

print(minMaxStats.getInfo())
print(minMaxStats.get('tmmx_min').getInfo())
print(minMaxStats.get('tmmx_max').getInfo())

# define visualization parameters
palette = [
        '1a3678', '2955bc', '5699ff', '8dbae9', 'acd1ff', 'caebff', 'e5f9ff',
        'fdffb4', 'ffe6a2', 'ffc969', 'ffa12d', 'ff7c1f', 'ca531a', 'ff0000',
        'ab0000'
    ]

# add to map
m.addLayer(aoiFC, {}, "AOI")
m.addLayer(terraClim_mean.select('tmmx'), 
           {'min': minMaxStats.get('tmmx_min'),
            'max': minMaxStats.get('tmmx_max'),
            'palette':palette}, 
           "Max temp")
m.addLayer(terraClim_mean.select('tmmn'), 
           {'min': minMaxStats.get('tmmn_min'),
            'max': minMaxStats.get('tmmn_max'),
            'palette':palette}, 
           "Min temp")
m.addLayer(terraClim_mean.select('pdsi'), 
           {'min': minMaxStats.get('pdsi_min'),
            'max': minMaxStats.get('pdsi_max'),
            'palette':palette}, 
           "PDSI")
m.addLayer(terraClim_mean.select('vpd'), 
           {'min': minMaxStats.get('vpd_min'),
            'max': minMaxStats.get('vpd_max'),
            'palette':palette}, 
           "VPD")
m.addLayer(terraClim_mean.select('def'), 
           {'min': minMaxStats.get('def_min'),
            'max': minMaxStats.get('def_max'),
            'palette':palette}, 
           "Water deficit")
m.addLayer(terraClim_mean.select('pr'), 
           {'min': minMaxStats.get('pr_min'),
            'max': minMaxStats.get('pr_max'),
            'palette':palette}, 
           "Precip")
m.addLayer(terraClim_mean.select('soil'), 
           {'min': minMaxStats.get('soil_min'),
            'max': minMaxStats.get('soil_max'),
            'palette':palette}, 
           "Soil moisture")

m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'def_max': 25.61666666666667, 'def_min': 0, 'pdsi_max': 1.09, 'pdsi_min': -1.8715000000000002, 'pr_max': 400.08333333333337, 'pr_min': 51, 'soil_max': 307.35, 'soil_min': 63.25, 'tmmn_max': 21.3, 'tmmn_min': 4.8999999999999995, 'tmmx_max': 31.200000000000003, 'tmmx_min': 18.8, 'vpd_max': 1.03, 'vpd_min': 0.59}
# 18.8
# 31.200000000000003
# Map(center=[-11.966886618395746, -70.5430491275674], controls=(WidgetControl(options=['position', 'transparent…

# %%
# check dates
# terraClimIC_filtered = terraClimIC_scaled.filterDate('2010-01-01', '2010-12-31')
# print("Images in 2010:", terraClimIC_filtered.size().getInfo())

print(terraClimIC_scaled.size().getInfo())

years = ee.List.sequence(2000, 2024)

def count_by_year(y):
    y = ee.Number(y)
    fc = terraClimIC_scaled.filterDate(
        ee.Date.fromYMD(y, 1, 1),
        ee.Date.fromYMD(y.add(1), 1, 1)
    )
    return ee.Feature(None, {
        'year': y,
        'count': fc.size()
    })

summary = ee.FeatureCollection(years.map(count_by_year))
# print(summary.getInfo())

simple = summary.aggregate_array('year').zip(
    summary.aggregate_array('count')
).getInfo()

for yr, cnt in simple:
    print(yr, cnt)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 300
# 2000 12
# 2001 12
# 2002 12
# 2003 12
# 2004 12
# 2005 12
# 2006 12
# 2007 12
# 2008 12
# 2009 12
# 2010 12
# 2011 12
# 2012 12
# 2013 12
# 2014 12
# 2015 12
# 2016 12
# 2017 12
# 2018 12
# 2019 12
# 2020 12
# 2021 12
# 2022 12
# 2023 12
# 2024 12

# %%
# export the gee image to the python environment

export_folder = "/home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim"

collection = terraClimIC_scaled

# Loop over images and export
for img_dict in collection.toList(collection.size()).getInfo():
    image = ee.Image(img_dict['id'])
    
    # Get the image date from system:time_start
    time_start = image.get('system:time_start').getInfo()  # milliseconds since epoch
    date = datetime.utcfromtimestamp(time_start / 1000)    # convert to datetime
    date_str = date.strftime('%Y_%m')                      # format YYYY_MM

    print(date_str)
    
    # Build output path with date in filename
    out_path = os.path.join(export_folder, f"terraClim_{date_str}.tif")

    # Export image locally
    geemap.ee_export_image(
        image,
        filename=out_path,
        region=aoiFC.geometry(),
        scale=res,
    )
    
    print(f"Exported {out_path}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 2000_01
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/columbia-phd/thumbnails/0efe08f1e7419d398f8f813a3b07d824-5f8c20492878b75e0570bf9e3c8273ff:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2000_01.tif
# Exported /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2000_01.tif
# 2000_02
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/columbia-phd/thumbnails/592ab112ed84512e6172f39eda8103af-cd931d4c7070ec085be9705bcd6ca351:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2000_02.tif
# Exported /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2000_02.tif
# 2000_03
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/columbia-phd/thumbnails/ffc27424985a662d1d5137d58e5cdc86-3dab9c6f81a7fb17cec48f85d3bcef7b:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2000_03.tif
# Exported /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2000_03.tif
# 2000_04
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/columbia-phd/thumbnails/6ff89a0e1e7191092e9e436fb3788a70-40a3b10e8b7a08d53551b089367c0977:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2000_04.tif
# Exported /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2000_04.tif
# 2000_05
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/columbia-phd/thumbnails/188282fe000ed867dee399e067789099-928f746aaa66bfe7fdd3bb9f1c1888da:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2000_05.tif
# Exported /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2000_05.tif
# 2000_06
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/columbia-phd/thumbnails/d9d49a12ba0febb3afdd4a59a52c456d-abfe48f0110c7a205f946341463e9395:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2000_06.tif
# Exported /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2000_06.tif
# 2000_07
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/columbia-phd/thumbnails/01c9027aa0adccf2b42aa200f6560d6b-40cadf5938bf67c6f9b7e4ee2b738ab2:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2000_07.tif
# Exported /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2000_07.tif
# 2000_08
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/columbia-phd/thumbnails/2ba85c9862de5316051db240c1ab4630-2c43cec4a59fa6daefbfd6707ce44dae:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2000_08.tif
# Exported /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2000_08.tif
# 2000_09
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/columbia-phd/thumbnails/e31e412f10d2c74f9e4faf27096656ea-d99c97da5665aa334ef2763dcf980cca:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2000_09.tif
# Exported /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2000_09.tif
# 2000_10
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/columbia-phd/thumbnails/e6037de88aa768074aa8acb4a3478a4b-6a07e889ea28816510bf3df534fdc3d5:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2000_10.tif
# Exported /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2000_10.tif
# 2000_11
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/columbia-phd/thumbnails/4dc52d948eb5996dfb8dc6a406cf21d4-54614de0c42725d559961324d1d19508:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2000_11.tif
# Exported /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2000_11.tif
# 2000_12
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/columbia-phd/thumbnails/05811788ce1c53bcbee76c9c9163fcac-2d222c8ddc68eaa261e58fc398268afc:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2000_12.tif
# Exported /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2000_12.tif
# 2001_01
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/columbia-phd/thumbnails/dc01006080d9cb49c073e6c5324091c5-e4de990dc3044106fc92a28d31d2ec7f:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2001_01.tif
# Exported /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2001_01.tif
# 2001_02
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/columbia-phd/thumbnails/d4204264468d4c754c5ab274bdb7e448-bcce2b6b7fcab098516876d20178be0e:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2001_02.tif
# Exported /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2001_02.tif
# 2001_03
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/columbia-phd/thumbnails/5e336c38ea3ab1d5b3a69fb9c0b914a8-fc558344598dec66832cf637b1fe34db:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2001_03.tif
# Exported /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2001_03.tif
# 2001_04
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/columbia-phd/thumbnails/b29d3008a537062136d28039bb705057-465a3c54ce5a4a59f4b89c4a5380c76a:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2001_04.tif
# Exported /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2001_04.tif
# 2001_05
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/columbia-phd/thumbnails/f890a230b6259a9563deea0f088cba04-73b8127827abe3893785cdcf02360a84:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2001_05.tif
# Exported /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2001_05.tif
# 2001_06
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/columbia-phd/thumbnails/47487645fbf33ca9c87b4002ebf1a40c-e829203e0559276fb3604c5046e8de6b:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2001_06.tif
# Exported /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2001_06.tif
# 2001_07
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/columbia-phd/thumbnails/e4a0fb9179909f9fae66a55f9dae03c4-507cb56ed34d0a205f75a3ac34608adc:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2001_07.tif
# Exported /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2001_07.tif
# 2001_08
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/columbia-phd/thumbnails/403b8b7071722698bc2e712fd1bf48ec-d0d833ff502f9b34cfd14619b50b0463:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2001_08.tif
# Exported /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2001_08.tif
# 2001_09
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/columbia-phd/thumbnails/f46051da8c8746a69fb2c797d8aec545-56cf292cbd4c94ab9efc53ef201af2fe:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2001_09.tif
# Exported /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2001
getPixels
# Please wait ...
# Data downloaded to /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2024_11.tif
# Exported /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2024_11.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/columbia-phd/thumbnails/0dda0a2f5d501209bb0817129d9ddff3-c8f4704e60f11d7a3ca34316957aeb30:getPixels
# Please wait ...
# Data downloaded to /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2024_12.tif
# Exported /home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2024_12.tif

# %%
# check export
# Path to your raster
raster_path = "/home/jovyan/MLEAEEE4000-DroughtAmazon2/data/TerraClim/terraClim_2001_03.tif"
band_number = 1

# Open raster using rasterio
with rasterio.open(raster_path) as src:
    raster = src.read(1)          # read first band
    transform = src.transform      # georeference info (optional)
    nodata = src.nodata
    print("Band count:", src.count)
    print("Band descriptions:", src.descriptions)
    print("Metadata:", src.meta)
    

# Mask nodata values
raster = np.ma.masked_equal(raster, nodata)

# Define your color palette
palette = [
    '#1a3678', '#2955bc', '#5699ff', '#8dbae9', '#acd1ff', '#caebff', '#e5f9ff',
    '#fdffb4', '#ffe6a2', '#ffc969', '#ffa12d', '#ff7c1f', '#ca531a', '#ff0000',
    '#ab0000'
]

cmap = ListedColormap(palette)

# Visualize
plt.figure(figsize=(10, 6))
plt.imshow(raster, cmap=cmap)
plt.colorbar(label='Raster values')
plt.title('Raster Visualization')
plt.axis('off')
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Band count: 7
# Band descriptions: (None, None, None, None, None, None, None)
# Metadata: {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 90, 'height': 86, 'count': 7, 'crs': CRS.from_wkt('GEOGCS["Greenwich",DATUM["unnamed",SPHEROID["unnamed",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST]]'), 'transform': Affine(0.041666666666666664, 0.0, -72.41666666666667,
#        0.0, -0.041666666666666664, -9.791666666666657)}

# %%
m = geemap.Map()
m.centerObject(aoiFC, zoom=7)

m.addLayer(terraClimIC
    .filter(ee.Filter.date('2001-03-01', '2001-03-31'))
    .select('tmmx')
    .first(), 
           {'min': 100,
            'max': 300,
            'palette':palette}, 
           "Max temp")

m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[-11.966886618395746, -70.5430491275674], controls=(WidgetControl(options=['position', 'transparent…

# %%
# check export
# Path to your raster
raster_path = "/home/jovyan/MLEAEEE4000-DroughtAmazon2/data/mdd_extent_TCscale.tif"
band_number = 1

# Open raster using rasterio
with rasterio.open(raster_path) as src:
    raster = src.read(1)          # read first band
    transform = src.transform      # georeference info (optional)
    nodata = src.nodata
    print("Band count:", src.count)
    print("Band descriptions:", src.descriptions)
    print("Metadata:", src.meta)
    

# Mask nodata values
raster = np.ma.masked_equal(raster, nodata)

# Define your color palette
palette = [
    '#1a3678', '#2955bc', '#5699ff', '#8dbae9', '#acd1ff', '#caebff', '#e5f9ff',
    '#fdffb4', '#ffe6a2', '#ffc969', '#ffa12d', '#ff7c1f', '#ca531a', '#ff0000',
    '#ab0000'
]

cmap = ListedColormap(palette)

# Visualize
plt.figure(figsize=(10, 6))
plt.imshow(raster, cmap=cmap)
plt.colorbar(label='Raster values')
plt.title('Raster Visualization')
plt.axis('off')
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Band count: 1
# Band descriptions: (None,)
# Metadata: {'driver': 'GTiff', 'dtype': 'uint8', 'nodata': 0.0, 'width': 90, 'height': 86, 'count': 1, 'crs': CRS.from_wkt('GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]'), 'transform': Affine(0.04166666666666666, 0.0, -72.41666666666669,
#        0.0, -0.04166666666666666, -9.791666666666643)}
