# %%
# install the eartgeneing-api and geemap
# !pip install earthengine-api 
# !pip install geemap
# Out:
# Requirement already satisfied: earthengine-api in /srv/conda/envs/notebook/lib/python3.12/site-packages (1.7.3)
# Requirement already satisfied: google-cloud-storage in /srv/conda/envs/notebook/lib/python3.12/site-packages (from earthengine-api) (3.5.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from earthengine-api) (2.187.0)
# Requirement already satisfied: google-auth>=1.4.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from earthengine-api) (2.41.1)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from earthengine-api) (0.2.1)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from earthengine-api) (0.31.0)
# Requirement already satisfied: requests in /srv/conda/envs/notebook/lib/python3.12/site-packages (from earthengine-api) (2.32.5)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from httplib2<1dev,>=0.9.2->earthengine-api) (3.2.5)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from google-api-python-client>=1.12.1->earthengine-api) (2.28.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from google-api-python-client>=1.12.1->earthengine-api) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (6.31.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.26.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from google-auth>=1.4.1->earthengine-api) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from google-auth>=1.4.1->earthengine-api) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from google-auth>=1.4.1->earthengine-api) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from requests->earthengine-api) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from requests->earthengine-api) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from requests->earthengine-api) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from requests->earthengine-api) (2025.10.5)
# Requirement already satisfied: pyasn1>=0.1.3 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth>=1.4.1->earthengine-api) (0.6.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from google-cloud-storage->earthengine-api) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from google-cloud-storage->earthengine-api) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from google-cloud-storage->earthengine-api) (1.7.1)
# Requirement already satisfied: geemap in /srv/conda/envs/notebook/lib/python3.12/site-packages (0.36.6)
# Requirement already satisfied: anywidget in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geemap) (0.9.19)
# Requirement already satisfied: bqplot in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geemap) (0.12.45)
# Requirement already satisfied: earthengine-api>=1.6.12 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geemap) (1.7.3)
# Requirement already satisfied: eerepr>=0.1.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geemap) (0.1.2)
# Requirement already satisfied: folium>=0.17.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geemap) (0.20.0)
# Requirement already satisfied: geocoder in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geemap) (1.38.1)
# Requirement already satisfied: ipyevents in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geemap) (2.0.4)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geemap) (0.6.0)
# Requirement already satisfied: ipyleaflet>=0.19.2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geemap) (0.20.0)
# Requirement already satisfied: matplotlib in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geemap) (3.10.7)
# Requirement already satisfied: numpy in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geemap) (2.3.4)
# Requirement already satisfied: pandas in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geemap) (2.3.3)
# Requirement already satisfied: plotly in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geemap) (6.5.0)
# Requirement already satisfied: pyperclip in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geemap) (1.11.0)
# Requirement already satisfied: pyshp>=2.3.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geemap) (3.0.2)
# Requirement already satisfied: python-box in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geemap) (7.3.2)
# Requirement already satisfied: scooby in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geemap) (0.11.0)
# Requirement already satisfied: google-cloud-storage in /srv/conda/envs/notebook/lib/python3.12/site-packages (from earthengine-api>=1.6.12->geemap) (3.5.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from earthengine-api>=1.6.12->geemap) (2.187.0)
# Requirement already satisfied: google-auth>=1.4.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from earthengine-api>=1.6.12->geemap) (2.41.1)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from earthengine-api>=1.6.12->geemap) (0.2.1)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from earthengine-api>=1.6.12->geemap) (0.31.0)
# Requirement already satisfied: requests in /srv/conda/envs/notebook/lib/python3.12/site-packages (from earthengine-api>=1.6.12->geemap) (2.32.5)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from httplib2<1dev,>=0.9.2->earthengine-api>=1.6.12->geemap) (3.2.5)
# Requirement already satisfied: branca>=0.6.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from folium>=0.17.0->geemap) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from folium>=0.17.0->geemap) (3.1.6)
# Requirement already satisfied: xyzservices in /srv/conda/envs/notebook/lib/python3.12/site-packages (from folium>=0.17.0->geemap) (2025.10.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.6.12->geemap) (2.28.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.6.12->geemap) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.6.12->geemap) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.6.12->geemap) (6.31.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.6.12->geemap) (1.26.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from google-auth>=1.4.1->earthengine-api>=1.6.12->geemap) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from google-auth>=1.4.1->earthengine-api>=1.6.12->geemap) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from google-auth>=1.4.1->earthengine-api>=1.6.12->geemap) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from requests->earthengine-api>=1.6.12->geemap) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from requests->earthengine-api>=1.6.12->geemap) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from requests->earthengine-api>=1.6.12->geemap) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from requests->earthengine-api>=1.6.12->geemap) (2025.10.5)
# Requirement already satisfied: pyasn1>=0.1.3 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth>=1.4.1->earthengine-api>=1.6.12->geemap) (0.6.1)
# Requirement already satisfied: ipywidgets in /srv/conda/envs/notebook/lib/python3.12/site-packages (from ipyfilechooser>=0.6.0->geemap) (8.1.7)
# Requirement already satisfied: jupyter-leaflet<0.21,>=0.20 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from ipyleaflet>=0.19.2->geemap) (0.20.0)
# Requirement already satisfied: traittypes<3,>=0.2.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from ipyleaflet>=0.19.2->geemap) (0.2.3)
# Requirement already satisfied: comm>=0.1.3 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (9.7.0)
# Requirement already satisfied: traitlets>=4.3.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.16)
# Requirement already satisfied: decorator>=4.3.2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.51)
# Requirement already satisfied: pygments>=2.11.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.6.3)
# Requirement already satisfied: wcwidth in /srv/conda/envs/notebook/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from jinja2>=2.9->folium>=0.17.0->geemap) (3.0.3)
# Requirement already satisfied: ptyprocess>=0.5 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.0)
# Requirement already satisfied: pure_eval in /srv/conda/envs/notebook/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.3)
# Requirement already satisfied: psygnal>=0.8.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from anywidget->geemap) (0.15.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from anywidget->geemap) (4.15.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from pandas->geemap) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from pandas->geemap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from pandas->geemap) (2025.2)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->geemap) (1.17.0)
# Requirement already satisfied: click in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geocoder->geemap) (8.3.0)
# Requirement already satisfied: future in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geocoder->geemap) (1.0.0)
# Requirement already satisfied: ratelim in /srv/conda/envs/notebook/lib/python3.12/site-packages (from geocoder->geemap) (0.1.6)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from google-cloud-storage->earthengine-api>=1.6.12->geemap) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from google-cloud-storage->earthengine-api>=1.6.12->geemap) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from google-cloud-storage->earthengine-api>=1.6.12->geemap) (1.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from matplotlib->geemap) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from matplotlib->geemap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from matplotlib->geemap) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from matplotlib->geemap) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from matplotlib->geemap) (25.0)
# Requirement already satisfied: pillow>=8 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from matplotlib->geemap) (12.0.0)
# Requirement already satisfied: narwhals>=1.15.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from plotly->geemap) (2.11.0)

# %%
import ee
# Trigger the authentication flow.
ee.Authenticate(force=True)

# Initialize the library.
# ee.Initialize(project='rock-appliance-477517-u5')
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/drive%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=tzFdbUvXBAWthBBi7doT_qL039JntH5h_f2RGYNBEmg&tc=fbRkklBwwEg7ZM9y_kFrKY9B3UZK-8gLJTYS1Fb--1o&cc=RI5MmZzvpK38ptwJ5tN-8Jnr5wf4MhyEcLjzMkOar3U>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/drive%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=tzFdbUvXBAWthBBi7doT_qL039JntH5h_f2RGYNBEmg&tc=fbRkklBwwEg7ZM9y_kFrKY9B3UZK-8gLJTYS1Fb--1o&cc=RI5MmZzvpK38ptwJ5tN-8Jnr5wf4MhyEcLjzMkOar3U</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code:  4/1ATX87lNTpEXFsYYgir7oRMQ4QE6eHPI-BngvmxwAhnLappOxLnGfniVIJ_4
# Successfully saved authorization token.

# %%
import rasterio
import geemap

# %%
# initialize the project library
ee.Initialize(project='columbia-phd')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# define administrative aoi
# gaul = ee.FeatureCollection("FAO/GAUL/2015/level1") # get the FAO feature collection
# peru = gaul.filter(ee.Filter.eq('ADM0_NAME', 'Peru')) # Filter Peru first (ADM0_NAME = country)
# aoi = peru.filter(ee.Filter.eq('ADM1_NAME', 'Madre de Dios')) # Filter Madre de Dios region (ADM1_NAME = admin1 region)

square = ee.Feature(
    ee.Geometry.Polygon([
        [[-73.489604265885, -9.106738678620076],
          [-73.489604265885, -14.471148538041154],
          [-67.72178200026, -14.471148538041154],
          [-67.72178200026, -9.106738678620076]]
    ])
)
aoi = ee.FeatureCollection([square])

# set the tree cover extent parameters (we consider forest all that is at least 30% canopy cover, at least 0.5 ha continuous, this is consistent with Hansen data handling)
canopy_cover = ee.Number(30) # canopy cover threshold (%)
min_extent = ee.Number(6) # min size threshold (6 pixels ≈ 0.5 ha)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# load the Hansen Global Forest Change data layer
gfc2024 = ee.Image("UMD/hansen/global_forest_change_2024_v1_12")

# get tree cover extent in 2000
canopyCover_2000 = gfc2024.select("treecover2000")

# mask the tree cover according to our tree cover parameters defined above
canopyCover30 = canopyCover_2000.gte(canopy_cover).selfMask() # all pixels in 2000 with at least 30% canopy cover, as defined by Hansen et al
contArea = canopyCover30.connectedPixelCount()
extent2000 = contArea.gte(min_extent).selfMask() # all pixels in 2000 with at least 0.5 ha of continuous forest

# Get projection and scale for visualization later on
prj = gfc2024.projection()
scale = prj.nominalScale()
print(scale.getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 27.829872698318393

# %%
# from the GFC dataset, get tree loss
treeLoss = gfc2024.select("loss")

# In the GFC dataset, any value in "loss" that is greater 0 idnicates a loss event. The value to this loss event indicates the year. We want no loss events, loss=0 
noLoss = treeLoss.eq(0)

# mask the 2000 extent by the noLoss
current_extent = extent2000.updateMask(noLoss)

# clip this to the aoi defined above
mdd_extent = current_extent.clip(aoi)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# get the nominal scale of the TerraClim data, our largest dataset
TerraClim = ee.ImageCollection('IDAHO_EPSCOR/TERRACLIMATE')
first = TerraClim.first()
TC_scale = first.projection().nominalScale()

print(TC_scale.getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 4638.312116386398

# %%
# Create map
m = geemap.Map()
m.centerObject(aoi, zoom=7)

# add to map
m.addLayer(aoi, {}, "AOI")
m.addLayer(mdd_extent, 
           {}, 
           "Hansen")

m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[-11.794669076434946, -70.60569313307249], controls=(WidgetControl(options=['position', 'transparen…

# %%
# rescale and reproject the image to the TC data scale
mdd_extent_mode = mdd_extent.reduceResolution(
    reducer=ee.Reducer.mode(),  # aggregation function
    maxPixels=65536
).reproject(
    crs=mdd_extent.projection(),
    scale=5000
)

# export the gee image to the python environment
out = "/home/jovyan/MLEAEEE4000-DroughtAmazon2/data/hansen_datamask_v2.tif"

geemap.ee_export_image(
    mdd_extent_mode,
    filename=out,
    scale=5000, # assign the scale value of the TC data
    region=aoi.geometry()
)

#Once you want to read in image again:
#with rasterio.open(out) as src:
    #arr = src.read(1)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/columbia-phd/thumbnails/25da29277887ac0dee5dec7194d322d6-6b060ae63eb9903f27e438956d8cc3de:getPixels
# Please wait ...
# An error occurred while downloading.
